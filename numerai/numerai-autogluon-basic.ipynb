# %%
# install dependencies
# !pip install pandas sklearn numerapi autogluon
# Out:
# ...
#      |████████████████████████████████| 48 kB 3.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 267 kB 30.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 189 kB 27.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 162 kB 32.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 59 kB 4.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 26.4 MB 53.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.5 MB 58.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 802 kB 56.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 132 kB 55.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.0 MB 55.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 39.8 MB 38.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 59.3 MB 68.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 293 kB 42.8 MB/s eta 0:00:01
# ...

# %%
# import dependencies
import pandas as pd
import numerapi
import sklearn.linear_model
import autogluon.core as ag
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# download the latest training dataset (takes around 30s)
training_data = pd.read_csv("https://numerai-public-datasets.s3-us-west-2.amazonaws.com/latest_numerai_training_data.csv.xz")
training_data.head()
# Out:
#                  id   era data_type  feature_intelligence1  \
# 0  n000315175b67977  era1     train                   0.00
# 1  n0014af834a96cdd  era1     train                   0.00
# 2  n001c93979ac41d4  era1     train                   0.25
# 3  n0034e4143f22a13  era1     train                   1.00
# 4  n00679d1a636062f  era1     train                   0.25
#
#    feature_intelligence2  feature_intelligence3  feature_intelligence4  \
# 0                   0.50                   0.25                   0.00
# 1                   0.00                   0.00                   0.25
# 2                   0.50                   0.25                   0.25
# 3                   0.00                   0.00                   0.50
# 4                   0.25                   0.25                   0.25
#
#    feature_intelligence5  feature_intelligence6  feature_intelligence7  ...  \
# 0                    0.5                   0.25                   0.25  ...
# ...

# %%
# find only the feature columns
feature_cols = training_data.columns[training_data.columns.str.startswith('feature')]
feature_cols = feature_cols.tolist()

# %%
# select those columns out of the training dataset
cols = feature_cols + ['target']
train_data = training_data[cols]

# %%
# create a model and fit the training data (~30 sec to run)
excluded_model_types = ['KNN', 'NN', 'custom']
predictor = TabularPredictor(label='target').fit(train_data=train_data, excluded_model_types=excluded_model_types, presets="best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220618_131043/"
# Presets specified: ['best_quality']
# ...
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220618_131043/"
# AutoGluon Version:  0.4.2
# Python Version:     3.9.12
# Operating System:   Linux
# Train Data Rows:    501808
# Train Data Columns: 310
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and label-values can't be converted to int).
# 	Label info (max, min, mean, stddev): (1.0, 0.0, 0.5, 0.22327)
# ...
