# %%
from numerapi import NumerAPI
from pathlib import Path
import os

# %%
print('Downloading dataset files...')
napi = NumerAPI()
current_round = napi.get_current_round()
Path("./v4").mkdir(parents=False, exist_ok=True)
if not os.path.exists("v4/train.parquet"):
    napi.download_dataset("v4/train.parquet")
if not os.path.exists("v4/validation.parquet"):
    napi.download_dataset("v4/validation.parquet")
if not os.path.exists(f"v4/live_{current_round}.parquet"):
    napi.download_dataset("v4/live.parquet", f"v4/live_{current_round}.parquet")
if not os.path.exists("v4/validation_example_preds.parquet"):
    napi.download_dataset("v4/validation_example_preds.parquet")
if not os.path.exists("v4/features.json"):
    napi.download_dataset("v4/features.json")
# Out:
# Downloading dataset files...

# %%
# read the feature metadata and get a feature set (or all the features)
import json
print('Reading minimal training data')
with open("v4/features.json", "r") as f:
    feature_metadata = json.load(f)
# Out:
# Reading minimal training data

# %%
# features = list(feature_metadata["feature_stats"].keys()) # get all the features
# features = feature_metadata["feature_sets"]["small"] # get the small feature set
features = feature_metadata["feature_sets"]["medium"] # get the medium feature set
features[:10]
# Out:
# ['feature_abating_unadaptable_weakfish',
#  'feature_ablest_mauritanian_elding',
#  'feature_acclimatisable_unfeigned_maghreb',
#  'feature_accommodable_crinite_cleft',
#  'feature_acetose_periotic_coronation',
#  'feature_additive_untrustworthy_hierologist',
#  'feature_adsorbed_blizzardy_burlesque',
#  'feature_affettuoso_taxidermic_greg',
#  'feature_afoul_valvate_faery',
#  'feature_agaze_lancinate_zohar']

# %%
# load training data
import pandas as pd
target = "target"
columns = features + [target]
training_data = pd.read_parquet('v4/train.parquet', columns=columns)

# %%
len(training_data)
# Out:
# 2420521

# %%
training_data = training_data.dropna()

# %%
len(training_data)
# Out:
# 2420521

# %%
training_data = training_data.head(100000)
training_data.head()
# Out:
#                   feature_abating_unadaptable_weakfish  \
# id
# n003bba8a98662e4                                  0.00
# n003bee128c2fcfc                                  1.00
# n0048ac83aff7194                                  1.00
# n00691bec80d3e02                                  0.25
# n00b8720a2fdc4f2                                  0.00
#
#                   feature_ablest_mauritanian_elding  \
# id
# n003bba8a98662e4                                1.0
# n003bee128c2fcfc                                0.5
# n0048ac83aff7194                                1.0
# n00691bec80d3e02                                1.0
# n00b8720a2fdc4f2                                0.5
#
#                   feature_acclimatisable_unfeigned_maghreb  \
# id
# n003bba8a98662e4                                      0.00
# n003bee128c2fcfc                                      0.50
# n0048ac83aff7194                                      0.50
# n00691bec80d3e02                                      0.25
# n00b8720a2fdc4f2                                      0.00
#
#                   feature_accommodable_crinite_cleft  \
# id
# n003bba8a98662e4                                1.00
# n003bee128c2fcfc                                0.50
# n0048ac83aff7194                                0.00
# n00691bec80d3e02                                0.25
# n00b8720a2fdc4f2                                0.00
#
#                   feature_acetose_periotic_coronation  \
# id
# n003bba8a98662e4                                 0.00
# n003bee128c2fcfc                                 0.75
# n0048ac83aff7194                                 0.00
# n00691bec80d3e02                                 0.00
# n00b8720a2fdc4f2                                 0.00
#
#                   feature_additive_untrustworthy_hierologist  \
# id
# n003bba8a98662e4                                        0.25
# n003bee128c2fcfc                                        0.25
# n0048ac83aff7194                                        1.00
# n00691bec80d3e02                                        0.50
# n00b8720a2fdc4f2                                        0.75
#
#                   feature_adsorbed_blizzardy_burlesque  \
# id
# n003bba8a98662e4                                  1.00
# n003bee128c2fcfc                                  0.75
# n0048ac83aff7194                                  0.25
# n00691bec80d3e02                                  0.25
# n00b8720a2fdc4f2                                  0.25
#
#                   feature_affettuoso_taxidermic_greg  \
# id
# n003bba8a98662e4                                0.00
# n003bee128c2fcfc                                0.50
# n0048ac83aff7194                                0.75
# n00691bec80d3e02                                0.50
# n00b8720a2fdc4f2                                0.00
#
#                   feature_afoul_valvate_faery  feature_agaze_lancinate_zohar  \
# id
# n003bba8a98662e4                         0.75                           0.00
# n003bee128c2fcfc                         0.50                           0.75
# n0048ac83aff7194                         0.50                           0.50
# n00691bec80d3e02                         1.00                           0.25
# n00b8720a2fdc4f2                         0.50                           0.00
#
#                   ...  feature_weightiest_protozoic_brawler  \
# id                ...
# n003bba8a98662e4  ...                                   1.0
# n003bee128c2fcfc  ...                                   0.0
# n0048ac83aff7194  ...                                   0.5
# n00691bec80d3e02  ...                                   0.5
# n00b8720a2fdc4f2  ...                                   0.0
#
#                   feature_wetter_unbaffled_loma  \
# id
# n003bba8a98662e4                           0.00
# n003bee128c2fcfc                           0.75
# n0048ac83aff7194                           0.75
# n00691bec80d3e02                           1.00
# n00b8720a2fdc4f2                           0.50
#
#                   feature_wheezier_unjaundiced_game  \
# id
# n003bba8a98662e4                               0.50
# n003bee128c2fcfc                               0.00
# n0048ac83aff7194                               0.25
# n00691bec80d3e02                               0.00
# n00b8720a2fdc4f2                               0.25
#
#                   feature_wistful_tussive_cycloserine  \
# id
# n003bba8a98662e4                                 1.00
# n003bee128c2fcfc                                 0.75
# n0048ac83aff7194                                 0.00
# n00691bec80d3e02                                 0.00
# n00b8720a2fdc4f2                                 0.75
#
#                   feature_witchy_orange_muley  \
# id
# n003bba8a98662e4                         0.00
# n003bee128c2fcfc                         0.75
# n0048ac83aff7194                         0.00
# n00691bec80d3e02                         0.50
# n00b8720a2fdc4f2                         0.25
#
#                   feature_wombed_liberatory_malva  \
# id
# n003bba8a98662e4                             0.00
# n003bee128c2fcfc                             0.75
# n0048ac83aff7194                             0.25
# n00691bec80d3e02                             0.25
# n00b8720a2fdc4f2                             0.25
#
#                   feature_wrathful_prolix_colotomy  \
# id
# n003bba8a98662e4                               1.0
# n003bee128c2fcfc                               0.0
# n0048ac83aff7194                               0.0
# n00691bec80d3e02                               0.5
# n00b8720a2fdc4f2                               0.0
#
#                   feature_wrought_muckier_temporality  \
# id
# n003bba8a98662e4                                 1.00
# n003bee128c2fcfc                                 0.50
# n0048ac83aff7194                                 0.75
# n00691bec80d3e02                                 0.75
# n00b8720a2fdc4f2                                 0.00
#
#                   feature_yelled_hysteretic_eath  target
# id
# n003bba8a98662e4                            0.50    0.25
# n003bee128c2fcfc                            0.75    0.75
# n0048ac83aff7194                            0.25    0.50
# n00691bec80d3e02                            0.50    0.75
# n00b8720a2fdc4f2                            0.25    0.75
#
# [5 rows x 473 columns]

# %%
# load test data
import pandas as pd
target = "target"
columns = features + [target]
test_data = pd.read_parquet('v4/validation.parquet', columns=columns)
len(test_data)
# Out:
# 2245885

# %%
test_data = test_data.dropna()
len(test_data)
# Out:
# 2219626

# %%
from pycaret.classification import *
reg101 = setup(data = training_data, fold_shuffle=True, test_data=test_data,target = 'target', session_id=123)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e9f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e9f8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3e9f8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e9f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e9f8_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3e9f8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e9f8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3e9f8_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e9f8_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_3e9f8_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e9f8_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_3e9f8_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e9f8_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_3e9f8_row4_col1" class="data row4 col1" >(100000, 473)</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e9f8_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_3e9f8_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e9f8_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_3e9f8_row6_col1" class="data row6 col1" >472</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e9f8_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_3e9f8_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e9f8_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_3e9f8_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3e9f8_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_3e9f8_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3e9f8_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_3e9f8_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3e9f8_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_3e9f8_row11_col1" class="data row11 col1" >(100000, 464)</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3e9f8_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_3e9f8_row12_col1" class="data row12 col1" >(2219626, 464)</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3e9f8_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_3e9f8_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3e9f8_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_3e9f8_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3e9f8_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_3e9f8_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3e9f8_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_3e9f8_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3e9f8_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_3e9f8_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3e9f8_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_3e9f8_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3e9f8_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_3e9f8_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3e9f8_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_3e9f8_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3e9f8_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_3e9f8_row21_col1" class="data row21 col1" >e295</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3e9f8_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_3e9f8_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3e9f8_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_3e9f8_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3e9f8_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_3e9f8_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3e9f8_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_3e9f8_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3e9f8_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_3e9f8_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3e9f8_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_3e9f8_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3e9f8_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_3e9f8_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3e9f8_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_3e9f8_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3e9f8_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_3e9f8_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_3e9f8_row30_col1" class="data row30 col1" >None</td>
#     </tr>
# 2022-06-18 11:29:55,012 INFO logs: create_model_container: 0
# 2022-06-18 11:29:55,013 INFO logs: master_model_container: 0
# 2022-06-18 11:29:55,013 INFO logs: display_container: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 from pycaret.classification import *
# ----> 2 reg101 = setup(data = training_data, fold_shuffle=True, test_data=test_data,target = 'target', session_id=123)
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/pycaret/classification.py:580, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     577 if log_plots == True:
#     578     log_plots = ["auc", "confusion_matrix", "feature"]
# --> 580 return pycaret.internal.tabular.setup(
#     581     ml_usecase="classification",
#     582     available_plots=available_plots,
#     583     data=data,
#     584     target=target,
#     585     train_size=train_size,
#     586     test_data=test_data,
#     587     preprocess=preprocess,
#     588     imputation_type=imputation_type,
#     589     iterative_imputation_iters=iterative_imputation_iters,
#     590     categorical_features=categorical_features,
#     591     categorical_imputation=categorical_imputation,
#     592     categorical_iterative_imputer=categorical_iterative_imputer,
#     593     ordinal_features=ordinal_features,
#     594     high_cardinality_features=high_cardinality_features,
#     595     high_cardinality_method=high_cardinality_method,
#     596     numeric_features=numeric_features,
#     597     numeric_imputation=numeric_imputation,
#     598     numeric_iterative_imputer=numeric_iterative_imputer,
#     599     date_features=date_features,
#     600     ignore_features=ignore_features,
#     601     normalize=normalize,
#     602     normalize_method=normalize_method,
#     603     transformation=transformation,
#     604     transformation_method=transformation_method,
#     605     handle_unknown_categorical=handle_unknown_categorical,
#     606     unknown_categorical_method=unknown_categorical_method,
#     607     pca=pca,
#     608     pca_method=pca_method,
#     609     pca_components=pca_components,
#     610     ignore_low_variance=ignore_low_variance,
#     611     combine_rare_levels=combine_rare_levels,
#     612     rare_level_threshold=rare_level_threshold,
#     613     bin_numeric_features=bin_numeric_features,
#     614     remove_outliers=remove_outliers,
#     615     outliers_threshold=outliers_threshold,
#     616     remove_multicollinearity=remove_multicollinearity,
#     617     multicollinearity_threshold=multicollinearity_threshold,
#     618     remove_perfect_collinearity=remove_perfect_collinearity,
#     619     create_clusters=create_clusters,
#     620     cluster_iter=cluster_iter,
#     621     polynomial_features=polynomial_features,
#     622     polynomial_degree=polynomial_degree,
#     623     trigonometry_features=trigonometry_features,
#     624     polynomial_threshold=polynomial_threshold,
#     625     group_features=group_features,
#     626     group_names=group_names,
#     627     feature_selection=feature_selection,
#     628     feature_selection_threshold=feature_selection_threshold,
#     629     feature_selection_method=feature_selection_method,
#     630     feature_interaction=feature_interaction,
#     631     feature_ratio=feature_ratio,
#     632     interaction_threshold=interaction_threshold,
#     633     fix_imbalance=fix_imbalance,
#     634     fix_imbalance_method=fix_imbalance_method,
#     635     data_split_shuffle=data_split_shuffle,
#     636     data_split_stratify=data_split_stratify,
#     637     fold_strategy=fold_strategy,
#     638     fold=fold,
#     639     fold_shuffle=fold_shuffle,
#     640     fold_groups=fold_groups,
#     641     n_jobs=n_jobs,
#     642     use_gpu=use_gpu,
#     643     custom_pipeline=custom_pipeline,
#     644     html=html,
#     645     session_id=session_id,
#     646     log_experiment=log_experiment,
#     647     experiment_name=experiment_name,
#     648     log_plots=log_plots,
#     649     log_profile=log_profile,
#     650     log_data=log_data,
#     651     silent=silent,
#     652     verbose=verbose,
#     653     profile=profile,
#     654     profile_kwargs=profile_kwargs,
#     655 )
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/pycaret/internal/tabular.py:1745, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1742 logger.info(f"master_model_container: {len(master_model_container)}")
#    1743 logger.info(f"display_container: {len(display_container)}")
# -> 1745 logger.info(str(prep_pipe))
#    1746 logger.info("setup() succesfully completed......................................")
#    1748 gc.collect()
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/pprint.py:153, in PrettyPrinter.pformat(self, object)
#     151 def pformat(self, object):
#     152     sio = _StringIO()
# --> 153     self._format(object, sio, 0, 0, {}, 0)
#     154     return sio.getvalue()
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/pprint.py:170, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     168     self._readable = False
#     169     return
# --> 170 rep = self._repr(object, context, level)
#     171 max_width = self._width - indent - allowance
#     172 if len(rep) > max_width:
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/pprint.py:431, in PrettyPrinter._repr(self, object, context, level)
#     430 def _repr(self, object, context, level):
# --> 431     repr, readable, recursive = self.format(object, context.copy(),
#     432                                             self._depth, level)
#     433     if not readable:
#     434         self._readable = False
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/utils/_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/utils/_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/utils/_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/utils/_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/utils/_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File ~/miniconda3/envs/env3.9/lib/python3.9/site-packages/sklearn/base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params"):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
best = compare_models(errors="raise")

# %%
model_name = "lightgbm"

# %%
model = create_model(model_name)
