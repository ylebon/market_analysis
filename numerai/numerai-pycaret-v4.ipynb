# %%
from numerapi import NumerAPI
from pathlib import Path
import os

# %%
print('Downloading dataset files...')
napi = NumerAPI()
current_round = napi.get_current_round()
Path("./v4").mkdir(parents=False, exist_ok=True)
if not os.path.exists("v4/train.parquet"):
    napi.download_dataset("v4/train.parquet")
if not os.path.exists("v4/validation.parquet"):
    napi.download_dataset("v4/validation.parquet")
if not os.path.exists(f"v4/live_{current_round}.parquet"):
    napi.download_dataset("v4/live.parquet", f"v4/live_{current_round}.parquet")
if not os.path.exists("v4/validation_example_preds.parquet"):
    napi.download_dataset("v4/validation_example_preds.parquet")
if not os.path.exists("v4/features.json"):
    napi.download_dataset("v4/features.json")
# Out:
# Downloading dataset files...

# %%
# read the feature metadata and get a feature set (or all the features)
import json
print('Reading minimal training data')
with open("v4/features.json", "r") as f:
    feature_metadata = json.load(f)
# Out:
# Reading minimal training data

# %%
# features = list(feature_metadata["feature_stats"].keys()) # get all the features
# features = feature_metadata["feature_sets"]["small"] # get the small feature set
features = feature_metadata["feature_sets"]["medium"] # get the medium feature set
features[:10]
# Out:
# ['feature_abating_unadaptable_weakfish',
#  'feature_ablest_mauritanian_elding',
#  'feature_acclimatisable_unfeigned_maghreb',
#  'feature_accommodable_crinite_cleft',
#  'feature_acetose_periotic_coronation',
#  'feature_additive_untrustworthy_hierologist',
#  'feature_adsorbed_blizzardy_burlesque',
#  'feature_affettuoso_taxidermic_greg',
#  'feature_afoul_valvate_faery',
#  'feature_agaze_lancinate_zohar']

# %%
# load training data
import pandas as pd
target = "target"
columns = features + [target]
training_data = pd.read_parquet('v4/train.parquet', columns=columns)

# %%
training_data.keys()
# Out:
# Index(['feature_abating_unadaptable_weakfish',
#        'feature_ablest_mauritanian_elding',
#        'feature_acclimatisable_unfeigned_maghreb',
#        'feature_accommodable_crinite_cleft',
#        'feature_acetose_periotic_coronation',
#        'feature_additive_untrustworthy_hierologist',
#        'feature_adsorbed_blizzardy_burlesque',
#        'feature_affettuoso_taxidermic_greg', 'feature_afoul_valvate_faery',
#        'feature_agaze_lancinate_zohar',
#        ...
#        'feature_weightiest_protozoic_brawler', 'feature_wetter_unbaffled_loma',
#        'feature_wheezier_unjaundiced_game',
#        'feature_wistful_tussive_cycloserine', 'feature_witchy_orange_muley',
#        'feature_wombed_liberatory_malva', 'feature_wrathful_prolix_colotomy',
#        'feature_wrought_muckier_temporality', 'feature_yelled_hysteretic_eath',
#        'target'],
#       dtype='object', length=473)

# %%
training_data = training_data.head(100000)
training_data.head()
# Out:
#                   feature_abating_unadaptable_weakfish  \
# id
# n003bba8a98662e4                                  0.00
# n003bee128c2fcfc                                  1.00
# n0048ac83aff7194                                  1.00
# n00691bec80d3e02                                  0.25
# n00b8720a2fdc4f2                                  0.00
#
#                   feature_ablest_mauritanian_elding  \
# id
# n003bba8a98662e4                                1.0
# n003bee128c2fcfc                                0.5
# n0048ac83aff7194                                1.0
# n00691bec80d3e02                                1.0
# n00b8720a2fdc4f2                                0.5
#
#                   feature_acclimatisable_unfeigned_maghreb  \
# id
# n003bba8a98662e4                                      0.00
# n003bee128c2fcfc                                      0.50
# n0048ac83aff7194                                      0.50
# n00691bec80d3e02                                      0.25
# n00b8720a2fdc4f2                                      0.00
#
#                   feature_accommodable_crinite_cleft  \
# id
# n003bba8a98662e4                                1.00
# n003bee128c2fcfc                                0.50
# n0048ac83aff7194                                0.00
# n00691bec80d3e02                                0.25
# n00b8720a2fdc4f2                                0.00
#
#                   feature_acetose_periotic_coronation  \
# id
# n003bba8a98662e4                                 0.00
# n003bee128c2fcfc                                 0.75
# n0048ac83aff7194                                 0.00
# n00691bec80d3e02                                 0.00
# n00b8720a2fdc4f2                                 0.00
#
#                   feature_additive_untrustworthy_hierologist  \
# id
# n003bba8a98662e4                                        0.25
# n003bee128c2fcfc                                        0.25
# n0048ac83aff7194                                        1.00
# n00691bec80d3e02                                        0.50
# n00b8720a2fdc4f2                                        0.75
#
#                   feature_adsorbed_blizzardy_burlesque  \
# id
# n003bba8a98662e4                                  1.00
# n003bee128c2fcfc                                  0.75
# n0048ac83aff7194                                  0.25
# n00691bec80d3e02                                  0.25
# n00b8720a2fdc4f2                                  0.25
#
#                   feature_affettuoso_taxidermic_greg  \
# id
# n003bba8a98662e4                                0.00
# n003bee128c2fcfc                                0.50
# n0048ac83aff7194                                0.75
# n00691bec80d3e02                                0.50
# n00b8720a2fdc4f2                                0.00
#
#                   feature_afoul_valvate_faery  feature_agaze_lancinate_zohar  \
# id
# n003bba8a98662e4                         0.75                           0.00
# n003bee128c2fcfc                         0.50                           0.75
# n0048ac83aff7194                         0.50                           0.50
# n00691bec80d3e02                         1.00                           0.25
# n00b8720a2fdc4f2                         0.50                           0.00
#
#                   ...  feature_weightiest_protozoic_brawler  \
# id                ...
# n003bba8a98662e4  ...                                   1.0
# n003bee128c2fcfc  ...                                   0.0
# n0048ac83aff7194  ...                                   0.5
# n00691bec80d3e02  ...                                   0.5
# n00b8720a2fdc4f2  ...                                   0.0
#
#                   feature_wetter_unbaffled_loma  \
# id
# n003bba8a98662e4                           0.00
# n003bee128c2fcfc                           0.75
# n0048ac83aff7194                           0.75
# n00691bec80d3e02                           1.00
# n00b8720a2fdc4f2                           0.50
#
#                   feature_wheezier_unjaundiced_game  \
# id
# n003bba8a98662e4                               0.50
# n003bee128c2fcfc                               0.00
# n0048ac83aff7194                               0.25
# n00691bec80d3e02                               0.00
# n00b8720a2fdc4f2                               0.25
#
#                   feature_wistful_tussive_cycloserine  \
# id
# n003bba8a98662e4                                 1.00
# n003bee128c2fcfc                                 0.75
# n0048ac83aff7194                                 0.00
# n00691bec80d3e02                                 0.00
# n00b8720a2fdc4f2                                 0.75
#
#                   feature_witchy_orange_muley  \
# id
# n003bba8a98662e4                         0.00
# n003bee128c2fcfc                         0.75
# n0048ac83aff7194                         0.00
# n00691bec80d3e02                         0.50
# n00b8720a2fdc4f2                         0.25
#
#                   feature_wombed_liberatory_malva  \
# id
# n003bba8a98662e4                             0.00
# n003bee128c2fcfc                             0.75
# n0048ac83aff7194                             0.25
# n00691bec80d3e02                             0.25
# n00b8720a2fdc4f2                             0.25
#
#                   feature_wrathful_prolix_colotomy  \
# id
# n003bba8a98662e4                               1.0
# n003bee128c2fcfc                               0.0
# n0048ac83aff7194                               0.0
# n00691bec80d3e02                               0.5
# n00b8720a2fdc4f2                               0.0
#
#                   feature_wrought_muckier_temporality  \
# id
# n003bba8a98662e4                                 1.00
# n003bee128c2fcfc                                 0.50
# n0048ac83aff7194                                 0.75
# n00691bec80d3e02                                 0.75
# n00b8720a2fdc4f2                                 0.00
#
#                   feature_yelled_hysteretic_eath  target
# id
# n003bba8a98662e4                            0.50    0.25
# n003bee128c2fcfc                            0.75    0.75
# n0048ac83aff7194                            0.25    0.50
# n00691bec80d3e02                            0.50    0.75
# n00b8720a2fdc4f2                            0.25    0.75
#
# [5 rows x 473 columns]

# %%
from pycaret.classification import *
reg101 = setup(data = training_data, target = 'target', normalize = True, session_id=123)
# Out:
# <style type="text/css">
# #T_92d6d_row29_col1, #T_92d6d_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_92d6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92d6d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_92d6d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92d6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92d6d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_92d6d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92d6d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_92d6d_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92d6d_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_92d6d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92d6d_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_92d6d_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92d6d_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_92d6d_row4_col1" class="data row4 col1" >(100000, 473)</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92d6d_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_92d6d_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92d6d_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_92d6d_row6_col1" class="data row6 col1" >472</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92d6d_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_92d6d_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_92d6d_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_92d6d_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_92d6d_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_92d6d_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_92d6d_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_92d6d_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_92d6d_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_92d6d_row11_col1" class="data row11 col1" >(69999, 464)</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_92d6d_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_92d6d_row12_col1" class="data row12 col1" >(30001, 464)</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_92d6d_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_92d6d_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_92d6d_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_92d6d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_92d6d_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_92d6d_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_92d6d_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_92d6d_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_92d6d_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_92d6d_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_92d6d_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_92d6d_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_92d6d_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_92d6d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_92d6d_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_92d6d_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_92d6d_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_92d6d_row21_col1" class="data row21 col1" >7cee</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_92d6d_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_92d6d_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_92d6d_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_92d6d_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_92d6d_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_92d6d_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_92d6d_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_92d6d_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_92d6d_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_92d6d_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_92d6d_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_92d6d_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_92d6d_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_92d6d_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_92d6d_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_92d6d_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_92d6d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_92d6d_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <t
# 2022-06-17 15:21:00,281 INFO logs: create_model_container: 0
# 2022-06-17 15:21:00,282 INFO logs: master_model_container: 0
# 2022-06-17 15:21:00,282 INFO logs: display_container: 1
# 2022-06-17 15:21:00,285 INFO logs: Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True, features_todrop=[],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='target',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 numeric_strat...
#                                                   target='target')),
#                 ('P_transform', 'passthrough'), ('binn', 'passthrough'),
#                 ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                 ('dummy', Dummify(target='target')),
#                 ('fix_perfect', Remove_100(target='target')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough')],
#          verbose=False)
# 2022-06-17 15:21:00,285 INFO logs: setup() succesfully completed......................................

# %%
best = compare_models(errors="raise")
# Out:
# 2022-06-17 15:35:11,236 INFO logs: Initializing compare_models()
# 2022-06-17 15:35:11,237 INFO logs: compare_models(include=None, fold=None, round=4, cross_validation=True, sort=Accuracy, n_select=1, budget_time=None, turbo=True, errors=raise, fit_kwargs=None, groups=None, experiment_custom_tags=None, probability_threshold=None, verbose=True, display=None, exclude=None)
# 2022-06-17 15:35:11,238 INFO logs: Checking exceptions
# 2022-06-17 15:35:11,240 INFO logs: Preparing display monitor
# 2022-06-17 15:35:11,240 INFO logs: Preparing display monitor
# IntProgress(value=0, description='Processing: ', max=84)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             15:35:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# 2022-06-17 15:35:11,258 INFO logs: Initializing Logistic Regression
# 2022-06-17 15:35:11,258 INFO logs: Total runtime is 6.953875223795573e-06 minutes
# 2022-06-17 15:35:11,263 INFO logs: SubProcess create_model() called ==================================
# 2022-06-17 15:35:11,263 INFO logs: Initializing create_model()
# 2022-06-17 15:35:11,264 INFO logs: create_model(estimator=lr, fold=StratifiedKFold(n_splits=10, random_state=None, shuffle=False), round=4, cross_validation=True, predict=True, fit_kwargs={}, groups=None, refit=False, verbose=False, system=False, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=<pycaret.internal.Display.Display object at 0x7f1a6d149100>, return_train_score=False, kwargs={})
# 2022-06-17 15:35:11,264 INFO logs: Checking exceptions
# 2022-06-17 15:35:11,264 INFO logs: Importing libraries
# 2022-06-17 15:35:11,265 INFO logs: Copying training dataset
# 2022-06-17 15:35:11,281 INFO logs: Defining folds
# 2022-06-17 15:35:11,282 INFO logs: Declaring metric variables
# 2022-06-17 15:35:11,286 INFO logs: Importing untrained model
# 2022-06-17 15:35:11,290 INFO logs: Logistic Regression Imported succesfully
# 2022-06-17 15:35:11,297 INFO logs: Starting cross validation
# 2022-06-17 15:35:11,298 INFO logs: Cross validating with StratifiedKFold(n_splits=10, random_state=None, shuffle=False), n_jobs=-1
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File /usr/lib/python3.8/queue.py:167, in Queue.get(self, block, timeout)
#     166     if not self._qsize():
# --> 167         raise Empty
#     168 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 best = compare_models(errors="raise")
#
# File ~/.local/lib/python3.8/site-packages/pycaret/classification.py:823, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display, parallel)
#     820     del params["parallel"]
#     821     return parallel.compare_models(compare_models, params)
# --> 823 return pycaret.internal.tabular.compare_models(
#     824     include=include,
#     825     exclude=exclude,
#     826     fold=fold,
#     827     round=round,
#     828     cross_validation=cross_validation,
#     829     sort=sort,
#     830     n_select=n_select,
#     831     budget_time=budget_time,
#     832     turbo=turbo,
#     833     errors=errors,
#     834     fit_kwargs=fit_kwargs,
#     835     groups=groups,
#     836     experiment_custom_tags=experiment_custom_tags,
#     837     probability_threshold=probability_threshold,
#     838     verbose=verbose,
#     839     display=display,
#     840 )
#
# File ~/.local/lib/python3.8/site-packages/pycaret/internal/tabular.py:2199, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, display)
#    2184 create_model_args = dict(
#    2185     estimator=model,
#    2186     system=False,
#    (...)
#    2196     refit=False,
#    2197 )
#    2198 if errors == "raise":
# -> 2199     model, model_fit_time = create_model_supervised(**create_model_args)
#    2200     model_results = pull(pop=True)
#    2201 else:
#
# File ~/.local/lib/python3.8/site-packages/pycaret/internal/tabular.py:3200, in create_model_supervised(estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, verbose, system, X_train_data, y_train_data, metrics, experiment_custom_tags, add_to_model_list, probability_threshold, display, return_train_score, **kwargs)
#    3197 logger.info(f"Cross validating with {cv}, n_jobs={n_jobs}")
#    3199 model_fit_start = time.time()
# -> 3200 scores = cross_validate(
#    3201     pipeline_with_model,
#    3202     data_X,
#    3203     data_y,
#    3204     cv=cv,
#    3205     groups=groups,
#    3206     scoring=metrics_dict,
#    3207     fit_params=fit_kwargs,
#    3208     n_jobs=n_jobs,
#    3209     return_train_score=return_train_score,
#    3210     error_score=0,
#    3211 )
#    3212 model_fit_end = time.time()
#    3213 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:242, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238 # We clone the estimator to make sure that all the folds are
#     239 # independent, and that it is pickle-able.
#     240 parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     241                     pre_dispatch=pre_dispatch)
# --> 242 scores = parallel(
#     243     delayed(_fit_and_score)(
#     244         clone(estimator), X, y, scorers, train, test, verbose, None,
#     245         fit_params, return_train_score=return_train_score,
#     246         return_times=True, return_estimator=return_estimator,
#     247         error_score=error_score)
#     248     for train, test in cv.split(X, y, groups))
#     250 zipped_scores = list(zip(*scores))
#     251 if return_train_score:
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:833, in Parallel.dispatch_one_batch(self, iterator)
#     830 n_jobs = self._cached_effective_n_jobs
#     831 big_batch_size = batch_size * n_jobs
# --> 833 islice = list(itertools.islice(iterator, big_batch_size))
#     834 if len(islice) == 0:
#     835     return False
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:242, in <genexpr>(.0)
#     238 # We clone the estimator to make sure that all the folds are
#     239 # independent, and that it is pickle-able.
#     240 parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     241                     pre_dispatch=pre_dispatch)
# --> 242 scores = parallel(
#     243     delayed(_fit_and_score)(
#     244         clone(estimator), X, y, scorers, train, test, verbose, None,
#     245         fit_params, return_train_score=return_train_score,
#     246         return_times=True, return_estimator=return_estimator,
#     247         error_score=error_score)
#     248     for train, test in cv.split(X, y, groups))
#     250 zipped_scores = list(zip(*scores))
#     251 if return_train_score:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:336, in _BaseKFold.split(self, X, y, groups)
#     330 if self.n_splits > n_samples:
#     331     raise ValueError(
#     332         ("Cannot have number of splits n_splits={0} greater"
#     333          " than the number of samples: n_samples={1}.")
#     334         .format(self.n_splits, n_samples))
# --> 336 for train, test in super().split(X, y, groups):
#     337     yield train, test
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:80, in BaseCrossValidator.split(self, X, y, groups)
#      78 X, y, groups = indexable(X, y, groups)
#      79 indices = np.arange(_num_samples(X))
# ---> 80 for test_index in self._iter_test_masks(X, y, groups):
#      81     train_index = indices[np.logical_not(test_index)]
#      82     test_index = indices[test_index]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:697, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     696 def _iter_test_masks(self, X, y=None, groups=None):
# --> 697     test_folds = self._make_test_folds(X, y)
#     698     for i in range(self.n_splits):
#     699         yield test_folds == i
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:649, in StratifiedKFold._make_test_folds(self, X, y)
#     647 allowed_target_types = ('binary', 'multiclass')
#     648 if type_of_target_y not in allowed_target_types:
# --> 649     raise ValueError(
#     650         'Supported target types are: {}. Got {!r} instead.'.format(
#     651             allowed_target_types, type_of_target_y))
#     653 y = column_or_1d(y)
#     655 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'continuous' instead.

# %%
model_name = "lightgbm"

# %%
model = create_model(model_name)
# Out:
# 2022-06-17 15:16:12,788 INFO logs: Initializing create_model()
# 2022-06-17 15:16:12,790 INFO logs: create_model(estimator=lightgbm, fold=None, round=4, cross_validation=True, predict=True, fit_kwargs=None, groups=None, refit=True, verbose=True, system=True, metrics=None, experiment_custom_tags=None, add_to_model_list=True, probability_threshold=None, display=None, return_train_score=False, kwargs={})
# 2022-06-17 15:16:12,790 INFO logs: Checking exceptions
# 2022-06-17 15:16:12,791 INFO logs: Preparing display monitor
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             15:35:11
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# Empty DataFrame
# Columns: [Fold, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# 2022-06-17 15:16:12,803 INFO logs: Importing libraries
# 2022-06-17 15:16:12,804 INFO logs: Copying training dataset
# 2022-06-17 15:16:12,820 INFO logs: Defining folds
# 2022-06-17 15:16:12,821 INFO logs: Declaring metric variables
# 2022-06-17 15:16:12,825 INFO logs: Importing untrained model
# 2022-06-17 15:16:12,830 INFO logs: Light Gradient Boosting Machine Imported succesfully
# 2022-06-17 15:16:12,837 INFO logs: Starting cross validation
# 2022-06-17 15:16:12,838 INFO logs: Cross validating with StratifiedKFold(n_splits=10, random_state=None, shuffle=False), n_jobs=-1
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File /usr/lib/python3.8/queue.py:167, in Queue.get(self, block, timeout)
#     166     if not self._qsize():
# --> 167         raise Empty
#     168 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 model = create_model(model_name)
#
# File ~/.local/lib/python3.8/site-packages/pycaret/classification.py:959, in create_model(estimator, fold, round, cross_validation, fit_kwargs, groups, probability_threshold, verbose, return_train_score, **kwargs)
#     843 def create_model(
#     844     estimator: Union[str, Any],
#     845     fold: Optional[Union[int, Any]] = None,
#    (...)
#     853     **kwargs,
#     854 ) -> Any:
#     856     """
#     857     This function trains and evaluates the performance of a given estimator
#     858     using cross validation. The output of this function is a score grid with
#    (...)
#     956
#     957     """
# --> 959     return pycaret.internal.tabular.create_model_supervised(
#     960         estimator=estimator,
#     961         fold=fold,
#     962         round=round,
#     963         cross_validation=cross_validation,
#     964         fit_kwargs=fit_kwargs,
#     965         groups=groups,
#     966         probability_threshold=probability_threshold,
#     967         verbose=verbose,
#     968         return_train_score=return_train_score,
#     969         **kwargs,
#     970     )
#
# File ~/.local/lib/python3.8/site-packages/pycaret/internal/tabular.py:3200, in create_model_supervised(estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, verbose, system, X_train_data, y_train_data, metrics, experiment_custom_tags, add_to_model_list, probability_threshold, display, return_train_score, **kwargs)
#    3197 logger.info(f"Cross validating with {cv}, n_jobs={n_jobs}")
#    3199 model_fit_start = time.time()
# -> 3200 scores = cross_validate(
#    3201     pipeline_with_model,
#    3202     data_X,
#    3203     data_y,
#    3204     cv=cv,
#    3205     groups=groups,
#    3206     scoring=metrics_dict,
#    3207     fit_params=fit_kwargs,
#    3208     n_jobs=n_jobs,
#    3209     return_train_score=return_train_score,
#    3210     error_score=0,
#    3211 )
#    3212 model_fit_end = time.time()
#    3213 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:72, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      67     warnings.warn("Pass {} as keyword args. From version 0.25 "
#      68                   "passing these as positional arguments will "
#      69                   "result in an error".format(", ".join(args_msg)),
#      70                   FutureWarning)
#      71 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72 return f(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:242, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238 # We clone the estimator to make sure that all the folds are
#     239 # independent, and that it is pickle-able.
#     240 parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     241                     pre_dispatch=pre_dispatch)
# --> 242 scores = parallel(
#     243     delayed(_fit_and_score)(
#     244         clone(estimator), X, y, scorers, train, test, verbose, None,
#     245         fit_params, return_train_score=return_train_score,
#     246         return_times=True, return_estimator=return_estimator,
#     247         error_score=error_score)
#     248     for train, test in cv.split(X, y, groups))
#     250 zipped_scores = list(zip(*scores))
#     251 if return_train_score:
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~/.local/lib/python3.8/site-packages/joblib/parallel.py:833, in Parallel.dispatch_one_batch(self, iterator)
#     830 n_jobs = self._cached_effective_n_jobs
#     831 big_batch_size = batch_size * n_jobs
# --> 833 islice = list(itertools.islice(iterator, big_batch_size))
#     834 if len(islice) == 0:
#     835     return False
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:242, in <genexpr>(.0)
#     238 # We clone the estimator to make sure that all the folds are
#     239 # independent, and that it is pickle-able.
#     240 parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     241                     pre_dispatch=pre_dispatch)
# --> 242 scores = parallel(
#     243     delayed(_fit_and_score)(
#     244         clone(estimator), X, y, scorers, train, test, verbose, None,
#     245         fit_params, return_train_score=return_train_score,
#     246         return_times=True, return_estimator=return_estimator,
#     247         error_score=error_score)
#     248     for train, test in cv.split(X, y, groups))
#     250 zipped_scores = list(zip(*scores))
#     251 if return_train_score:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:336, in _BaseKFold.split(self, X, y, groups)
#     330 if self.n_splits > n_samples:
#     331     raise ValueError(
#     332         ("Cannot have number of splits n_splits={0} greater"
#     333          " than the number of samples: n_samples={1}.")
#     334         .format(self.n_splits, n_samples))
# --> 336 for train, test in super().split(X, y, groups):
#     337     yield train, test
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:80, in BaseCrossValidator.split(self, X, y, groups)
#      78 X, y, groups = indexable(X, y, groups)
#      79 indices = np.arange(_num_samples(X))
# ---> 80 for test_index in self._iter_test_masks(X, y, groups):
#      81     train_index = indices[np.logical_not(test_index)]
#      82     test_index = indices[test_index]
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:697, in StratifiedKFold._iter_test_masks(self, X, y, groups)
#     696 def _iter_test_masks(self, X, y=None, groups=None):
# --> 697     test_folds = self._make_test_folds(X, y)
#     698     for i in range(self.n_splits):
#     699         yield test_folds == i
#
# File ~/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:649, in StratifiedKFold._make_test_folds(self, X, y)
#     647 allowed_target_types = ('binary', 'multiclass')
#     648 if type_of_target_y not in allowed_target_types:
# --> 649     raise ValueError(
#     650         'Supported target types are: {}. Got {!r} instead.'.format(
#     651             allowed_target_types, type_of_target_y))
#     653 y = column_or_1d(y)
#     655 _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
#
# ValueError: Supported target types are: ('binary', 'multiclass'). Got 'continuous' instead.
